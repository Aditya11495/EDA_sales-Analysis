# %%
import pandas as pd
import numpy as np
np.random.seed(42)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
n = 1000

# %%
data = {
    "Order_ID": range(1, n + 1),
    "Product": np.random.choice(["Laptop", "Phone", "Tablet", "Headphones"], n),
    "Region": np.random.choice(["North", "South", "East", "West"], n),
    "Sales": np.random.randint(1000, 50000, n),
    "Quantity": np.random.randint(1, 5, n),
    "Profit": np.random.randint(-5000, 15000, n),
    "Order_Date": pd.date_range(start="2024-01-01", periods=n, freq="D")
}

# %%
df = pd.DataFrame(data)
df.to_csv("sales_data.csv", index=False)

print("Dataset Created Successfully!")
print(df.head())
# Out:
# Dataset Created Successfully!
#    Order_ID     Product Region  Sales  Quantity  Profit Order_Date
# 0         1      Tablet  South  21491         3     779 2024-01-01
# 1         2  Headphones   East   2341         4   -1170 2024-01-02
# 2         3      Laptop  North  45623         3    4046 2024-01-03
# 3         4      Tablet  North  25791         4    4794 2024-01-04
# 4         5      Tablet  North   1338         2   -4559 2024-01-05

# %%
df.isnull().sum()
# Out:
# Order_ID      0
# Product       0
# Region        0
# Sales         0
# Quantity      0
# Profit        0
# Order_Date    0
# dtype: int64

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Month'] = df['Order_Date'].dt.month

monthly_sales = df.groupby('Month')['Sales'].sum()

monthly_sales.plot(kind='line', marker='o')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()

# %%
product_sales = df.groupby('Product')['Sales'].sum()

product_sales.plot(kind='bar')
plt.title("Sales by Product")
plt.show()

# %%
sns.histplot(df['Profit'], kde=True)
plt.title("Profit Distribution")
plt.show()

# %%
region_sales = df.groupby('Region')['Sales'].sum()

region_sales.plot(kind='pie', autopct='%1.1f%%')
plt.title("Regional Sales Distribution")
plt.show()
